# %% [markdown]
# #### About the Dataset

# %% [markdown]
# Dataset: [`The CirCor DigiScope Phonocardiogram Dataset`](https://physionet.org/content/circor-heart-sound/1.0.3/)

# %% [markdown]
# > 5272 heart sound recordings were collected from the main four auscultation locations of 1568 subjects, aged between 0 and 21 years (mean ± STD = 6.1 ± 4.3 years), with a duration between 4.8 to 80.4 seconds (mean ± STD = 22.9 ± 7.4 s), totaling more than 33.5 hours of recording.
#
# Fundamental heart sounds (namely S1 and S2) are generated from vibrations of the cardiac valves as they open and close during the cardiac cycle. Valve malfunctioning causes turbulence in the blood flow within heart chambers and near the heart, which translates into abnormal sounds known as murmurs.
# As such, for clinical auscultations of each heart valve, the stethoscope is ideally placed at specific locations:
#
# - Aortic valve: second intercostal space, right sternal border
# - Pulmonic valve: second intercostal space, left sternal border
# - Tricuspid valve: left lower sternal border
# - Mitral valve: fifth intercostal space, midclavicular line (cardiac apex)

# %% [markdown]
# #### Data Description
# There are four data file types in the dataset (per subject):
#
# - A wave recording file (binary .wav format) per auscultation location for each subject, which contains the heart sound data
# - A header file (text .hea format) describing the .wav file using the standard WFDB format
# - A segmentation data file (text .tsv format) per auscultation location for all subjects, which contains segmentation information regarding the start and end points of the fundamental heart sounds S1 and S2
# - A subject description text file (text .txt format) per subject, where the name of the file corresponds to the subject ID. Demographic data such as weight, height, sex, age group and pregnancy status as well as a detailed description of murmur events are provided in this file.

# %% [markdown]
# The file `training_data.csv` contains the overall information for all the records of the training set in the PhysioNet Challenge 2022;
# - PV corresponds to the pulmonary valve point;
# - TV corresponds to the tricuspid valve point;
# - AV corresponds to the aortic valve point;
# - MV corresponds to the mitral valve point;
# - Phc for any other auscultation Location.
#
# | ![Image 1](image1.jpeg) | ![Image 2](image2.jpeg) | ![Image 3](image3.jpeg) |
# |------------------------|------------------------|------------------------|
# | Image 1    | Image 2     | Image 3     |

# %% [markdown]
# #### Subject Description File Variables
# | Variable                | Description                                                                       | Possible values                                                                                  |
# |-------------------------|-----------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------|
# | **Age**                 | Age category (string)                                                             | Neonate, Infant, Child, Adolescent, Young adult                                                   |
# | **Sex**                 | Reported sex (string)                                                             | Female, Male                                                                                      |
# | **Height**              | Height in centimeters (number)                                                    | > 0                                                                                              |
# | **Weight**              | Weight in kilograms (number)                                                      | > 0                                                                                              |
# | **Pregnancy status**     | Did the subject report being pregnant at the time of the examination? (boolean)   | True, False                                                                                       |
# | **Additional ID**        | The second record identifier for subjects that participated in both campaigns (string) | Subject identifier                                                                                |
# | **Campaign**            | Campaign attended by the subject (string)                                         | CC2014, CC2015                                                                                    |
# | **Murmur**              | Indicates if a murmur is present, absent, or unidentifiable for the annotator (string) | Present, Absent, Unknown                                                                          |
# | **Murmur locations**     | Auscultation locations where at least one murmur has been observed (string)       | Any combination of PV, TV, AV, MV, Phc separated by plus (+) signs                                |
# | **Most audible location**| Auscultation location where murmurs sounded more intense for the annotator (string) | PV, TV, AV, MV, Phc                                                                               |
# | **Systolic murmur timing**| Timing of the murmur in the systolic period (string)                             | Early-systolic, Holosystolic, Late-systolic, Mid-systolic                                         |
# | **Systolic murmur shape**| Shape of the murmur in the systolic period (string)                              | Crescendo, Decrescendo, Diamond, Plateau                                                          |
# | **Systolic murmur pitch**| Pitch of the murmur in the systolic period (string)                              | Low, Medium, High                                                                                 |
# | **Systolic murmur grading**| Grading of the murmur in the systolic period according to the Levine's scale (string) | I/VI, II/VI, III/VI                                                                               |
# | **Systolic murmur quality**| Quality of the murmur in the systolic period (string)                          | Blowing, Harsh, Musical                                                                           |
# | **Diastolic murmur timing**| Timing of the murmur in the diastolic period (string)                          | Early-diastolic, Holodiastolic, Mid-diastolic                                                     |
# | **Diastolic murmur shape**| Shape of the murmur in the diastolic period (string)                            | Decrescendo, Plateau                                                                              |
# | **Diastolic murmur pitch**| Pitch of the murmur in the diastolic period (string)                            | Low, Medium, High                                                                                 |
# | **Diastolic murmur grading**| Grading of the murmur in the diastolic period according to the Levine scale (string) | I/IV, II/IV, III/IV                                                                               |
# | **Diastolic murmur quality**| Quality of the murmur in the diastolic period (string)                        | Blowing, Harsh                                                                                    |
# | **Outcome**             | The expert cardiologist's overall diagnosis                                       | Normal, Abnormal                                                                                  |

# %% [markdown]
# ### Heart Valve Diseases and Their Associated Murmurs
#
# | **Heart Condition**                    | **Murmur Type**               | **Timing**               | **Location**                                    | **Radiation**                   | **Quality**                | **Pitch**           | **Additional Sounds**                                                                 |
# |----------------------------------------|-------------------------------|--------------------------|-------------------------------------------------|---------------------------------|----------------------------|---------------------|---------------------------------------------------------------------------------------------------|
# | **Aortic Stenosis**                    | Systolic ejection murmur       | Mid-systolic             | Right second intercostal space (aortic area)    | Radiates to the carotids        | Harsh or grating           | Medium-to-high      | Soft, split second heart sound (S2)                                                             |
# | **Mitral Regurgitation**               | Holosystolic (pansystolic)     | Throughout systole       | Apex of the heart                               | Radiates to the left axilla      | Blowing or whooshing       | High                | S3 heart sound due to increased volume returning to the left atrium                               |
# | **Aortic Regurgitation**               | Diastolic decrescendo murmur   | Early diastole           | Left sternal border (third or fourth intercostal space) | None                          | Blowing                   | High                | Austin Flint murmur (mid-to-late diastolic murmur at the apex), regurgitant jet on mitral valve   |
# | **Mitral Stenosis**                    | Diastolic rumble               | Mid-to-late diastole     | Apex of the heart                               | Rarely radiates                 | Low-pitched, rumbling      | Low                 | Opening snap (OS), accentuated S1 sound                                                          |
# | **Tricuspid Regurgitation**            | Holosystolic murmur            | Throughout systole       | Left lower sternal border                       | Radiates to the right lower sternal border | Blowing          | Medium             | Increases in intensity with inspiration (Carvallo’s sign)                                         |
# | **Pulmonic Stenosis**                  | Systolic ejection murmur       | Mid-systolic             | Left upper sternal border (second intercostal space) | Radiates to the left clavicle or neck | Harsh       | Medium             | Wide split S2 sound, pulmonary ejection click                                                    |
# | **Tricuspid Stenosis**                 | Diastolic rumble               | Mid-to-late diastole     | Left lower sternal border                       | None                            | Rumbling                  | Low                 | Accentuated by inspiration                                                                     |
# | **Pulmonic Regurgitation**             | Diastolic decrescendo murmur   | Early diastole           | Left upper sternal border                       | None                            | Blowing                   | High or low         | High-pitched if due to pulmonary hypertension, low-pitched for less severe causes                |
# | **Mitral Valve Prolapse**              | Mid-systolic click followed by a murmur | Late systolic   | Apex of the heart                               | Radiates to the left axilla or base of the heart | Blowing         | Medium             | Mid-systolic click due to prolapsing valve leaflets                                             |
# | **Hypertrophic Obstructive Cardiomyopathy (HOCM)** | Systolic ejection murmur | Mid-systolic | Left lower sternal border                       | Radiates to the apex of the heart | Harsh             | Medium             | Murmur increases with Valsalva maneuver and decreases with squatting                             |
# | **Septal Defects (ASD, VSD)**          | Holosystolic murmur            | Throughout systole       | Left lower sternal border (VSD) or left upper sternal border (ASD) | Radiates across the precordium | Harsh or blowing         | High                | Fixed splitting of S2 in ASD, prominent murmur in VSD                                            |
# | **Patent Ductus Arteriosus (PDA)**     | Continuous "machinery" murmur  | Continuous               | Left infraclavicular area                       | Radiates to the back             | Harsh or machine-like      | Medium-to-high      | Loudest at S2, heard throughout systole and diastole                                             |
# | **Pulmonary Hypertension**             | High-pitched diastolic murmur  | Early diastole           | Left upper sternal border                       | None                            | Blowing                   | High                | Often associated with a loud pulmonary component of the second heart sound                        |
# | **Ebstein's Anomaly**                  | Holosystolic murmur            | Throughout systole       | Left lower sternal border                       | None                            | Blowing                   | Medium             | Associated with tricuspid regurgitation                                                          |
# | **Coarctation of the Aorta**           | Systolic murmur                | Mid-systolic             | Left upper sternal border                       | Radiates to the back             | Harsh                     | Medium             | May be associated with a continuous murmur if collateral vessels are present                     |

# %% [markdown]
# <div style="border: 3px solid #00008b; padding: 15px; border-radius: 5px; background-color: #000000; color: #ffffff;">
# <b>Summary</b>
#
# Heart valve diseases are associated with characteristic murmurs that provide clues to their diagnosis. These murmurs vary in timing (systolic vs. diastolic), pitch, quality, and location, helping clinicians to determine the underlying valve pathology. Correct interpretation of murmurs is essential for diagnosing and managing heart valve diseases effectively.
# </div>

# %%
from scipy.io import wavfile as wav
from scipy.signal import butter, lfilter
import IPython.display as ipd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fs, data = wav.read("training_data/2530_PV.wav")

# %%
ipd.Audio("training_data/2530_PV.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("training_data/2530_TV.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("training_data/2530_MV.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("training_data/2530_AV.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fs, data.size
# Out:
# (4000, 52224)

# %%
def plot_signal(data, fs, n_samples): 
    plt.plot((1./fs)*np.array(range(n_samples)), data[:n_samples])
    plt.xlabel("time (s)")
    plt.ylabel("amplitude")
    
def butterworth_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butterworth_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butterworth_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

def extract_frequency_bands(data, fs, filter_frequency_bands):
    data_filtered = np.zeros((len(data), 4))
    for k, band in enumerate(filter_frequency_bands):
        data_filtered[:, k] = butterworth_bandpass_filter(data, band[0], band[1], fs)
    return data_filtered

# %%
filter_frequency_bands = [(25, 45), (45, 80), (80, 200), (200, 400)]
data_filtered = extract_frequency_bands(data, fs, filter_frequency_bands)

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 6))
fig.suptitle("Filtered Frequency Bands of Heart Sound Signal", fontsize=16)
 
for k in range(4):
    row = k // 2  
    col = k % 2   
    axes[row, col].plot((1./fs)*np.array(range(1000)), data_filtered[:1000, k])
    axes[row, col].set_title("Frequencies %i-%i Hz" % filter_frequency_bands[k])
    axes[row, col].set_xlabel("Time (s)")
    axes[row, col].set_ylabel("Amplitude")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
df = pd.read_csv('training_data.csv')
df.sample(7)
# Out:
#      Patient ID Recording locations:         Age     Sex  Height  Weight  \
# 387       50774             AV+TV+MV  Adolescent    Male   150.0    38.5
# 283       50348       AV+AV+PV+TV+MV       Child  Female   137.0    32.1
# 347       50713          AV+PV+TV+MV       Child    Male   132.0    27.8
# 699       84930          AV+PV+TV+MV       Child  Female     NaN     NaN
# 820       85139             PV+TV+MV       Child    Male   143.0    33.3
# 381       50766          AV+PV+TV+MV         NaN  Female     NaN     NaN
# 543       69161          AV+PV+TV+MV       Child  Female   133.0    47.7
#
#      Pregnancy status  Murmur Murmur locations Most audible location  ...  \
# 387             False  Absent              NaN                   NaN  ...
# 283             False  Absent              NaN                   NaN  ...
# 347             False  Absent              NaN                   NaN  ...
# 699             False  Absent              NaN                   NaN  ...
# ...
